# %% [markdown]
# <a href="https://colab.research.google.com/github/ernanhughes/youtube-summarizer/blob/main/Text_to_Video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Steps for generating video from text
#
# 1. Use openai to generate a video script from a topic
# 2. Use edgetts to pick a voice and create a audio based on the above generated script
# 3. Use whisper and get timed captions for the above audio
# 4. Now generate visual keywords for the video script using openai api
# 5. Fetch videos based on the above visual keywords using pexels api
# 6. Stich together the videos, audio and captions using Moviepy

# %% [markdown]
# ![text_to_video_process.png](data:image/png;base64,...)

# %% [markdown]
# ### Install python 3.11

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.11
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11 1
# !sudo update-alternatives --config python3
# !sudo apt-get install -y python3.11-distutils
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.11 get-pip.py
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 257 kB in 2s (133 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.11 is already the newest version (3.11.11-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 55 not upgraded.
# There is only one alternative in link group python3 (providing /usr/bin/python3): /usr/bin/python3.11
# Nothing to configure.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.11-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 55 not upgraded.
# --2025-01-03 00:05:15--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2275758 (2.2M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.17M  --.-KB/s    in 0.05s
#
# 2025-01-03 00:05:15 (45.1 MB/s) - ‘get-pip.py’ saved [2275758/2275758]
#
# Collecting pip
#   Using cached pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Using cached pip-24.3.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-24.3.1

# %%
# !git clone https://github.com/SamurAIGPT/Text-To-Video-AI
# Out:
# fatal: destination path 'Text-To-Video-AI' already exists and is not an empty directory.

# %%
# %cd Text-To-Video-AI
# Out:
# /content/Text-To-Video-AI/Text-To-Video-AI

# %% [markdown]
# ### Install dependencies

# %%
# !pip3.11 install -r requirements.txt
# Out:
# Requirement already satisfied: aiohttp==3.9.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (3.9.5)
# Requirement already satisfied: aiosignal==1.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: annotated-types==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: anyio==4.4.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (4.4.0)
# Requirement already satisfied: attrs==23.2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: certifi==2024.7.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (2024.7.4)
# Requirement already satisfied: charset-normalizer==3.3.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: Cython==3.0.10 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (3.0.10)
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: distro==1.9.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: dtw-python==1.5.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: edge-tts==6.1.12 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (6.1.12)
# Requirement already satisfied: filelock==3.14.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (3.14.0)
# Requirement already satisfied: frozenlist==1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (1.4.1)
# Requirement already satisfied: fsspec==2024.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2024.6.0)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (1.0.5)
# Requirement already satisfied: httpx==0.27.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (0.27.0)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (3.7)
# Requirement already satisfied: imageio==2.34.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (2.34.1)
# Requirement already satisfied: imageio-ffmpeg==0.5.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (0.5.1)
# Requirement already satisfied: Jinja2==3.1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (3.1.4)
# Requirement already satisfied: llvmlite==0.42.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (0.42.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (2.1.5)
# Requirement already satisfied: more-itertools==10.2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (10.2.0)
# Requirement already satisfied: moviepy==1.0.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (1.0.3)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: multidict==6.0.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (6.0.5)
# Requirement already satisfied: networkx==3.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (3.3)
# Requirement already satisfied: numba==0.59.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 30)) (0.59.1)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (1.26.4)
# Requirement already satisfied: openai==1.31.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (1.31.1)
# Requirement already satisfied: openai-whisper==20231117 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (20231117)
# Requirement already satisfied: pillow==10.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 34)) (10.3.0)
# Requirement already satisfied: proglog==0.1.10 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 35)) (0.1.10)
# Requirement already satisfied: pydantic==2.7.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 36)) (2.7.3)
# Requirement already satisfied: pydantic_core==2.18.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 37)) (2.18.4)
# Requirement already satisfied: regex==2024.5.15 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 38)) (2024.5.15)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 39)) (2.32.3)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 40)) (1.13.1)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 41)) (1.3.1)
# Requirement already satisfied: sympy==1.12.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (1.12.1)
# Requirement already satisfied: tiktoken==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 43)) (0.7.0)
# Requirement already satisfied: torch==2.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 44)) (2.3.1)
# Requirement already satisfied: tqdm==4.66.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 45)) (4.66.4)
# Requirement already satisfied: typing_extensions==4.12.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 46)) (4.12.1)
# Requirement already satisfied: urllib3==2.2.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 47)) (2.2.1)
# Requirement already satisfied: whisper-timestamped==1.15.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 48)) (1.15.4)
# Requirement already satisfied: yarl==1.9.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 49)) (1.9.4)
# Requirement already satisfied: groq==0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 50)) (0.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from imageio-ffmpeg==0.5.1->-r requirements.txt (line 21)) (75.6.0)
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20231117->-r requirements.txt (line 33)) (2.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1->-r requirements.txt (line 44)) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->-r requirements.txt (line 44)) (12.6.85)

# %% [markdown]
# ### Setup api keys

# %%
import os

#for text generation, use openai or groq. groq model used: "llama3-70b-8192"
#note: use just one
from google.colab import userdata

os.environ["OPENAI_KEY"] = userdata.get('OPENAI_KEY')
os.environ['GROQ_API_KEY'] = userdata.get('GROQ_API_KEY')

os.environ["PEXELS_KEY"] = userdata.get('PEXELS_KEY')

# %%
# !apt install imagemagick &> /dev/null
# !sed -i '/<policy domain="path" rights="none" pattern="@\*"/d' /etc/ImageMagick-6/policy.xml

# %% [markdown]
# ### Generate video from topic

# %%
# !python3.11 app.py "Meditation"
# Out:
# script: Did you know?
# - Meditation can physically change your brain, increasing gray matter in areas related to learning, memory, and emotion regulation.
# - It can also decrease the density of gray matter in the amygdala, reducing stress and anxiety.
# - Regular meditation can even enhance your immune system and improve your focus.
# - Some of the world's top performers, like Steve Jobs and Oprah Winfrey, swear by meditation for productivity and mental clarity.
# - There are many types of meditation, from mindfulness to transcendental, so anyone can find a method that works for them.
# Detected language: English
# 100% 3422/3422 [00:12<00:00, 268.76frames/s]
# [((0, 0.66), 'Did you know'), ((0.66, 2.48), 'Meditation can'), ((2.48, 2.9), 'physically'), ((2.9, 3.44), 'change your'), ((3.44, 3.69), 'brain'), ((3.69, 4.66), 'increasing grey'), ((4.66, 5.2), 'matter in'), ((5.2, 5.92), 'areas related'), ((5.92, 6.44), 'to learning'), ((6.44, 7.28), 'memory and'), ((7.28, 7.6), 'emotion'), ((7.6, 8.12), 'regulation It'), ((8.12, 9.88), 'can also'), ((9.88, 10.26), 'decrease the'), ((10.26, 10.8), 'density of'), ((10.8, 11.54), 'grey matter'), ((11.54, 11.76), 'in the'), ((11.76, 12.32), 'amygdala'), ((12.32, 13.2), 'reducing stress'), ((13.2, 13.88), 'and anxiety'), ((13.88, 15.24), 'Regular'), ((15.24, 15.8), 'meditation can'), ((15.8, 16.8), 'even enhance'), ((16.8, 17.3), 'your immune'), ((17.3, 17.66), 'system and'), ((17.66, 18.25), 'improve your'), ((18.25, 18.9), 'focus Some'), ((18.9, 20.86), "of the world's"), ((20.86, 21.48), 'top performers'), ((21.48, 21.86), 'like Steve'), ((21.86, 22.44), 'Jobs and'), ((22.44, 22.98), 'Oprah Winfrey'), ((22.98, 23.46), 'swear by'), ((23.46, 24.54), 'meditation for'), ((24.54, 25.42), 'productivity'), ((25.42, 25.72), 'and mental'), ((25.72, 26.42), 'clarity There'), ((26.42, 27.64), 'are many'), ((27.64, 27.98), 'types of'), ((27.98, 28.88), 'meditation from'), ((28.88, 29.82), 'mindfulness to'), ((29.82, 30.8), 'transcendental'), ((30.8, 30.8), 'so anyone'), ((30.8, 31.54), 'can find'), ((31.54, 32.08), 'a method'), ((32.08, 32.48), 'that works'), ((32.48, 32.92), 'for them')]
# Content Script: Did you know?
# - Meditation can physically change your brain, increasing gray matter in areas related to learning, memory, and emotion regulation.
# - It can also decrease the density of gray matter in the amygdala, reducing stress and anxiety.
# - Regular meditation can even enhance your immune system and improve your focus.
# - Some of the world's top performers, like Steve Jobs and Oprah Winfrey, swear by meditation for productivity and mental clarity.
# - There are many types of meditation, from mindfulness to transcendental, so anyone can find a method that works for them.
# Timed Captions:((0, 0.66), 'Did you know')((0.66, 2.48), 'Meditation can')((2.48, 2.9), 'physically')((2.9, 3.44), 'change your')((3.44, 3.69), 'brain')((3.69, 4.66), 'increasing grey')((4.66, 5.2), 'matter in')((5.2, 5.92), 'areas related')((5.92, 6.44), 'to learning')((6.44, 7.28), 'memory and')((7.28, 7.6), 'emotion')((7.6, 8.12), 'regulation It')((8.12, 9.88), 'can also')((9.88, 10.26), 'decrease the')((10.26, 10.8), 'density of')((10.8, 11.54), 'grey matter')((11.54, 11.76), 'in the')((11.76, 12.32), 'amygdala')((12.32, 13.2), 'reducing stress')((13.2, 13.88), 'and anxiety')((13.88, 15.24), 'Regular')((15.24, 15.8), 'meditation can')((15.8, 16.8), 'even enhance')((16.8, 17.3), 'your immune')((17.3, 17.66), 'system and')((17.66, 18.25), 'improve your')((18.25, 18.9), 'focus Some')((18.9, 20.86), "of the world's")((20.86, 21.48), 'top performers')((21.48, 21.86), 'like Steve')((21.86, 22.44), 'Jobs and')((22.44, 22.98), 'Oprah Winfrey')((22.98, 23.46), 'swear by')((23.46, 24.54), 'meditation for')((24.54, 25.42), 'productivity')((25.42, 25.72), 'and mental')((25.72, 26.42), 'clarity There')((26.42, 27.64), 'are many')((27.64, 27.98), 'types of')((27.98, 28.88), 'meditation from')((28.88, 29.82), 'mindfulness to')((29.82, 30.8), 'transcendental')((30.8, 30.8), 'so anyone')((30.8, 31.54), 'can find')((31.54, 32.08), 'a method')((32.08, 32.48), 'that works')((32.48, 32.92), 'for them')
#
# Text [[[0, 0.66], ["thought bubble", "question mark", "curiosity"]], [[0.66, 2.48], ["meditation", "mindfulness", "relaxation"]], [[2.48, 2.9], ["brain shape", "neuron", "grey matter"]], [[2.9, 3.44], ["brain change", "growth icon", "progress"]], [[3.44, 3.69], ["brain model", "anatomy", "neuron"]], [[3.69, 4.66], ["increase symbol", "growth chart", "progress"]], [[4.66, 5.2], ["learning icon", "memory symbol", "brain"]], [[5.2, 5.92], ["memory concept", "brain connections", "neuron"]], [[5.92, 6.44], ["emotion regulation", "calmness", "peace"]], [[6.44, 7.28], ["memory improvement", "learning curve", "focus"]], [[7.28, 7.6], ["emotion control", "regulation symbol", "calm"]], [[7.6, 8.12], ["brain improvement", "neuron growth", "progress"]], [[8.12, 9.88], ["meditation benefits", "stress reduction", "relaxation"]], [[9.88, 10.26], ["decrease symbol", "less stress", "anxiety reduction"]], [[10.26, 10.8], ["brain scan", "grey matter", "science"]], [[10.8, 11.54], ["amygdala model", "brain anatomy", "neuron"]], [[11.54, 11.76], ["amygdala icon", "brain symbol", "fear"]], [[11.76, 12.32], ["stress reduction", "anxiety relief", "calmness"]], [[12.32, 13.2], ["anxiety concept", "fear symbol", "stress"]], [[13.2, 13.88], ["relaxation technique", "calmness symbol", "peace"]], [[13.88, 15.24], ["meditation practice", "regular exercise", "habit"]], [[15.24, 15.8], ["meditation benefits", "immune system", "health"]], [[15.8, 16.8], ["immune system boost", "health improvement", "wellness"]], [[16.8, 17.3], ["immune system icon", "health symbol", "wellness"]], [[17.3, 17.66], ["health concept", "wellness symbol", "fitness"]], [[17.66, 18.25], ["focus concept", "mental clarity", "concentration"]], [[18.25, 18.9], ["focus symbol", "mental clarity icon", "attention"]], [[18.9, 20.86], ["world globe", "map icon", "international"]], [[20.86, 21.48], ["top performers", "success symbol", "achievement"]], [[21.48, 21.86], ["Steve Jobs", "Oprah Winfrey", "influencers"]], [[21.86, 22.44], ["success story", "influencer icon", "motivation"]], [[22.44, 22.98], ["Oprah Winfrey icon", "influencer symbol", "motivation"]], [[22.98, 23.46], ["meditation practice", "productivity symbol", "focus"]], [[23.46, 24.54], ["productivity concept", "efficiency symbol", "success"]], [[24.54, 25.42], ["mental clarity icon", "focus symbol", "awareness"]], [[25.42, 25.72], ["mental clarity concept", "awareness symbol", "peace"]], [[25.72, 26.42], ["clarity symbol", "awareness icon", "mental peace"]], [[26.42, 27.64], ["meditation types", "mindfulness concept", "relaxation"]], [[27.64, 27.98], ["meditation options", "choice symbol", "variety"]], [[27.98, 28.88], ["mindfulness icon", "meditation symbol", "relaxation"]], [[28.88, 29.82], ["transcendental icon", "meditation concept", "spirituality"]], [[29.82, 30.8], ["meditation practice", "anyone can meditate", "inclusion"]], [[30.8, 31.54], ["meditation for all", "inclusive symbol", "accessibility"]], [[31.54, 32.08], ["method concept", "meditation approach", "technique"]], [[32.08, 32.48], [" meditation technique", "effective symbol", "success"]], [[32.48, 32.92], ["effective meditation", "success symbol", "achievement"]]]
# [[[0, 0.66], ['thought bubble', 'question mark', 'curiosity']], [[0.66, 2.48], ['meditation', 'mindfulness', 'relaxation']], [[2.48, 2.9], ['brain shape', 'neuron', 'grey matter']], [[2.9, 3.44], ['brain change', 'growth icon', 'progress']], [[3.44, 3.69], ['brain model', 'anatomy', 'neuron']], [[3.69, 4.66], ['increase symbol', 'growth chart', 'progress']], [[4.66, 5.2], ['learning icon', 'memory symbol', 'brain']], [[5.2, 5.92], ['memory concept', 'brain connections', 'neuron']], [[5.92, 6.44], ['emotion regulation', 'calmness', 'peace']], [[6.44, 7.28], ['memory improvement', 'learning curve', 'focus']], [[7.28, 7.6], ['emotion control', 'regulation symbol', 'calm']], [[7.6, 8.12], ['brain improvement', 'neuron growth', 'progress']], [[8.12, 9.88], ['meditation benefits', 'stress reduction', 'relaxation']], [[9.88, 10.26], ['decrease symbol', 'less stress', 'anxiety reduction']], [[10.26, 10.8], ['brain scan', 'grey matter', 'science']], [[10.8, 11.54], ['amygdala model', 'brain anatomy', 'neuron']], [[11.54, 11.76], ['amygdala icon', 'brain symbol', 'fear']], [[11.76, 12.32], ['stress reduction', 'anxiety relief', 'calmness']], [[12.32, 13.2], ['anxiety concept', 'fear symbol', 'stress']], [[13.2, 13.88], ['relaxation technique', 'calmness symbol', 'peace']], [[13.88, 15.24], ['meditation practice', 'regular exercise', 'habit']], [[15.24, 15.8], ['meditation benefits', 'immune system', 'health']], [[15.8, 16.8], ['immune system boost', 'health improvement', 'wellness']], [[16.8, 17.3], ['immune system icon', 'health symbol', 'wellness']], [[17.3, 17.66], ['health concept', 'wellness symbol', 'fitness']], [[17.66, 18.25], ['focus concept', 'mental clarity', 'concentration']], [[18.25, 18.9], ['focus symbol', 'mental clarity icon', 'attention']], [[18.9, 20.86], ['world globe', 'map icon', 'international']], [[20.86, 21.48], ['top performers', 'success symbol', 'achievement']], [[21.48, 21.86], ['Steve Jobs', 'Oprah Winfrey', 'influencers']], [[21.86, 22.44], ['success story', 'influencer icon', 'motivation']], [[22.44, 22.98], ['Oprah Winfrey icon', 'influencer symbol', 'motivation']], [[22.98, 23.46], ['meditation practice', 'productivity symbol', 'focus']], [[23.46, 24.54], ['productivity concept', 'efficiency symbol', 'success']], [[24.54, 25.42], ['mental clarity icon', 'focus symbol', 'awareness']], [[25.42, 25.72], ['mental clarity concept', 'awareness symbol', 'peace']], [[25.72, 26.42], ['clarity symbol', 'awareness icon', 'mental peace']], [[26.42, 27.64], ['meditation types', 'mindfulness concept', 'relaxation']], [[27.64, 27.98], ['meditation options', 'choice symbol', 'variety']], [[27.98, 28.88], ['mindfulness icon', 'meditation symbol', 'relaxation']], [[28.88, 29.82], ['transcendental icon', 'meditation concept', 'spirituality']], [[29.82, 30.8], ['meditation practice', 'anyone can meditate', 'inclusion']], [[30.8, 31.54], ['meditation for all', 'inclusive symbol', 'accessibility']], [[31.54, 32.08], ['method concept', 'meditation approach', 'technique']], [[32.08, 32.48], [' meditation technique', 'effective symbol', 'success']], [[32.48, 32.92], ['effective meditation', 'success symbol', 'achievement']]]
# [[[0, 0.66], 'https://videos.pexels.com/video-files/857131/857131-hd_1920_1080_24fps.mp4'], [[0.66, 2.48], 'https://videos.pexels.com/video-files/3327959/3327959-hd_1920_1080_24fps.mp4'], [[2.48, 2.9], 'https://videos.pexels.com/video-files/3129576/3129576-hd_1920_1080_30fps.mp4'], [[2.9, 3.44], 'https://videos.pexels.com/video-files/4587757/4587757-hd_1920_1080_25fps.mp4'], [[3.44, 3.69], 'https://videos.pexels.com/video-files/19282244/19282244-hd_1920_1080_25fps.mp4'], [[3.69, 4.66], 'https://videos.pexels.com/video-files/5849638/5849638-hd_1920_1080_30fps.mp4'], [[4.66, 5.2], 'https://videos.pexels.com/video-files/4961506/4961506-hd_1920_1080_25fps.mp4'], [[5.2, 5.92], 'https://videos.pexels.com/video-files/3761460/3761460-hd_1920_1080_25fps.mp4'], [[5.92, 6.44], 'https://videos.pexels.com/video-files/2297636/2297636-hd_1920_1080_30fps.mp4'], [[6.44, 7.28], 'https://videos.pexels.com/video-files/5733273/5733273-hd_1920_1080_30fps.mp4'], [[7.28, 7.6], 'https://videos.pexels.com/video-files/7914850/7914850-hd_1920_1080_30fps.mp4'], [[7.6, 8.12], 'https://videos.pexels.com/video-files/5544312/5544312-hd_1920_1080_24fps.mp4'], [[8.12, 9.88], 'https://videos.pexels.com/video-files/6703639/6703639-hd_1920_1080_25fps.mp4'], [[9.88, 10.26], 'https://videos.pexels.com/video-files/29955340/12855173_1920_1080_30fps.mp4'], [[10.26, 10.8], 'https://videos.pexels.com/video-files/6010766/6010766-hd_1920_1080_25fps.mp4'], [[10.8, 11.54], 'https://videos.pexels.com/video-files/29985923/12867001_1920_1080_25fps.mp4'], [[11.54, 11.76], 'https://videos.pexels.com/video-files/6025488/6025488-hd_1920_1080_24fps.mp4'], [[11.76, 12.32], 'https://videos.pexels.com/video-files/8313076/8313076-hd_1920_1080_30fps.mp4'], [[12.32, 13.2], 'https://videos.pexels.com/video-files/7280523/7280523-hd_1920_1080_25fps.mp4'], [[13.2, 13.88], 'https://videos.pexels.com/video-files/4587907/4587907-hd_1920_1080_25fps.mp4'], [[13.88, 15.24], 'https://videos.pexels.com/video-files/6892456/6892456-hd_1920_1080_25fps.mp4'], [[15.24, 15.8], 'https://videos.pexels.com/video-files/3125825/3125825-hd_1920_1080_25fps.mp4'], [[15.8, 16.8], 'https://videos.pexels.com/video-files/30026991/12882394_1920_1080_60fps.mp4'], [[16.8, 17.3], 'https://videos.pexels.com/video-files/5809671/5809671-hd_1920_1080_24fps.mp4'], [[17.3, 17.66], 'https://videos.pexels.com/video-files/4148673/4148673-hd_1920_1080_25fps.mp4'], [[17.66, 18.25], 'https://videos.pexels.com/video-files/4623605/4623605-hd_1920_1080_24fps.mp4'], [[18.25, 18.9], 'https://videos.pexels.com/video-files/5199824/5199824-hd_1920_1080_25fps.mp4'], [[18.9, 20.86], 'https://videos.pexels.com/video-files/7841863/7841863-hd_1920_1080_30fps.mp4'], [[20.86, 21.48], 'https://videos.pexels.com/video-files/5658056/5658056-hd_1920_1080_24fps.mp4'], [[21.48, 21.86], 'https://videos.pexels.com/video-files/3209211/3209211-hd_1920_1080_25fps.mp4'], [[21.86, 22.44], 'https://videos.pexels.com/video-files/4105022/4105022-hd_1920_1080_30fps.mp4'], [[22.44, 22.98], 'https://videos.pexels.com/video-files/7451172/7451172-hd_1920_1080_25fps.mp4'], [[22.98, 23.46], 'https://videos.pexels.com/video-files/8480738/8480738-hd_1920_1080_25fps.mp4'], [[23.46, 24.54], 'https://videos.pexels.com/video-files/8135701/8135701-hd_1920_1080_25fps.mp4'], [[24.54, 25.42], 'https://videos.pexels.com/video-files/28701282/12456077_1920_1080_24fps.mp4'], [[25.42, 25.72], 'https://videos.pexels.com/video-files/7531060/7531060-hd_1920_1080_25fps.mp4'], [[25.72, 26.42], 'https://videos.pexels.com/video-files/5964114/5964114-hd_1920_1080_25fps.mp4'], [[26.42, 27.64], 'https://videos.pexels.com/video-files/29987280/12867502_1920_1080_30fps.mp4'], [[27.64, 27.98], 'https://videos.pexels.com/video-files/30011548/12876398_1920_1080_50fps.mp4'], [[27.98, 28.88], 'https://videos.pexels.com/video-files/4446869/4446869-hd_1920_1080_25fps.mp4'], [[28.88, 29.82], 'https://videos.pexels.com/video-files/5849603/5849603-hd_1920_1080_30fps.mp4'], [[29.82, 30.8], 'https://videos.pex ...
# None
# Moviepy - Building video rendered_video.mp4.
# MoviePy - Writing audio in rendered_videoTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video rendered_video.mp4
#
# Moviepy - Done !
# Moviepy - video ready rendered_video.mp4
# rendered_video.mp4

# %% [markdown]
# ### Display video

# %%
from IPython.display import HTML
from base64 import b64encode
import datetime
import shutil


def add_timestamp_to_filename(filename):
    # Get the current timestamp
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

    # Separate the filename and its extension
    name, ext = filename.rsplit(".", 1)

    # Add the timestamp and reassemble the filename
    new_filename = f"{name}_{timestamp}.{ext}"
    return new_filename

# Path to the video file
original_filename = "rendered_video.mp4"
video_path = add_timestamp_to_filename(original_filename)
print(f"video path: {video_path}")

# Move the file
try:
    shutil.move(original_filename, video_path)
    print(f"File moved from {original_filename} to {video_path}")
except FileNotFoundError:
    print(f"The source file {original_filename} does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")



# Function to display video
def display_video(video_path, width=640, height=480):
    # Load video
    video_file = open(video_path, "rb").read()
    video_url = "data:video/mp4;base64," + b64encode(video_file).decode()
    return HTML(f"""
    <video width={width} height={height} controls>
        <source src="{video_url}" type="video/mp4">
    </video>
    """)

# Display video
display_video(video_path)
# Out:
# video path: rendered_video_20250103_003536.mp4
# File moved from rendered_video.mp4 to rendered_video_20250103_003536.mp4
#     <video width=640 height=480 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>
